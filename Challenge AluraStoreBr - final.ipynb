# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
faturamento_lojas = {}

faturamento_loja = round(sum(loja['Preço']),2)
faturamento_loja2 = round(sum(loja2['Preço']),2)
faturamento_loja3 = round(sum(loja3['Preço']),2)
faturamento_loja4 = round(sum(loja4['Preço']),2)
soma_faturamento_lojas = faturamento_loja + faturamento_loja2 + faturamento_loja3 + faturamento_loja4

faturamento_lojas["Loja 1"] = faturamento_loja
faturamento_lojas["Loja 2"] = faturamento_loja2
faturamento_lojas["Loja 3"] = faturamento_loja3
faturamento_lojas["Loja 4"] = faturamento_loja4


print(f'Faturamento da Loja 1: R$ {faturamento_loja:,.2f}')
print(f'Faturamento da Loja 2: R$ {faturamento_loja2:,.2f}')
print(f'Faturamento da Loja 3: R$ {faturamento_loja3:,.2f}')
print(f'Faturamento da Loja 4: R$ {faturamento_loja4:,.2f}')
print(f'Somando o resultado das 4 lojas, temos um faturamento total de R$ {soma_faturamento_lojas:,.2f}')
# Out:
# Faturamento da Loja 1: R$ 1,534,509.12
# Faturamento da Loja 2: R$ 1,488,459.06
# Faturamento da Loja 3: R$ 1,464,025.03
# Faturamento da Loja 4: R$ 1,384,497.58
# Somando o resultado das 4 lojas, temos um faturamento total de R$ 5,871,490.79

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# 1. Criar um dicionario para cada loja
# 2. Criar uma laço for para rodar na coluna de categorias.
# 3. Criar uma função para identificar a loja que vendeu mais

# %%
# - Loja 1
# - Criar dicionario das categorias
categorias_loja1 = {}

for categoria in loja['Categoria do Produto']:
    if categoria in categorias_loja1:
        categorias_loja1[categoria] += 1
    else:
        categorias_loja1[categoria] = 1

# - Função para identificar categoria mais vendida
def identificar_maior_categoria():
    maior_categoria_nome = ''
    maior_categoria_valor = 0
    for categoria, valor in categorias_loja1.items():
        if valor > maior_categoria_valor:
            maior_categoria_valor = valor
            maior_categoria_nome = categoria
    return maior_categoria_nome, maior_categoria_valor

categoria_mais_vendida_loja1 = identificar_maior_categoria()
# Out:
# A categoria mais vendida na loja 1 foi: ('moveis', 465)

# %%
# - Loja 2
# - Criar dicionario das categorias
categorias_loja2 = {}

for categoria in loja2['Categoria do Produto']:
    if categoria in categorias_loja2:
        categorias_loja2[categoria] += 1
    else:
        categorias_loja2[categoria] = 1

# - Função para identificar categoria mais vendida
def identificar_maior_categoria():
    maior_categoria_nome = ''
    maior_categoria_valor = 0
    for categoria, valor in categorias_loja2.items():
        if valor > maior_categoria_valor:
            maior_categoria_valor = valor
            maior_categoria_nome = categoria
    return maior_categoria_nome, maior_categoria_valor

categoria_mais_vendida_loja2 = identificar_maior_categoria()
# Out:
# A categoria mais vendida na loja 2 foi: ('moveis', 442)

# %%
# - Loja 3
# - Criar dicionario das categorias
categorias_loja3 = {}

for categoria in loja3['Categoria do Produto']:
    if categoria in categorias_loja3:
        categorias_loja3[categoria] += 1
    else:
        categorias_loja3[categoria] = 1

# - Função para identificar categoria mais vendida
def identificar_maior_categoria():
    maior_categoria_nome = ''
    maior_categoria_valor = 0
    for categoria, valor in categorias_loja3.items():
        if valor > maior_categoria_valor:
            maior_categoria_valor = valor
            maior_categoria_nome = categoria
    return maior_categoria_nome, maior_categoria_valor

categoria_mais_vendida_loja3 = identificar_maior_categoria()
# Out:
# A categoria mais vendida na loja 3 foi: ('moveis', 499)

# %%
# - Loja 4
# - Criar dicionario das categorias
categorias_loja4 = {}

for categoria in loja4['Categoria do Produto']:
    if categoria in categorias_loja4:
        categorias_loja4[categoria] += 1
    else:
        categorias_loja4[categoria] = 1

# - Função para identificar categoria mais vendida
def identificar_maior_categoria():
    maior_categoria_nome = ''
    maior_categoria_valor = 0
    for categoria, valor in categorias_loja4.items():
        if valor > maior_categoria_valor:
            maior_categoria_valor = valor
            maior_categoria_nome = categoria
    return maior_categoria_nome, maior_categoria_valor

categoria_mais_vendida_loja4 = identificar_maior_categoria()
# Out:
# A categoria mais vendida na loja 4 foi: ('moveis', 480)

# %%
# Mostrar a categoria mais vendida
print(f'A categoria mais vendida na loja 1 foi: {categoria_mais_vendida_loja1}')
print(f'A categoria mais vendida na loja 2 foi: {categoria_mais_vendida_loja2}')
print(f'A categoria mais vendida na loja 3 foi: {categoria_mais_vendida_loja3}')
print(f'A categoria mais vendida na loja 4 foi: {categoria_mais_vendida_loja4}')
# Out:
# A categoria mais vendida na loja 1 foi: ('moveis', 465)
# A categoria mais vendida na loja 2 foi: ('moveis', 442)
# A categoria mais vendida na loja 3 foi: ('moveis', 499)
# A categoria mais vendida na loja 4 foi: ('moveis', 480)

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# 1. Criar uma função para calcular a média
# 2. Imprimir a avaialção média por loja

# %%
# Loja 1
def media(lista):
  calculo = sum(lista) / len(lista)
  return calculo

media_loja1 = round(media(loja['Avaliação da compra']),2)
media_loja1
# Out:
# 3.98

# %%
# Loja 2
def media(lista):
  calculo = sum(lista) / len(lista)
  return calculo

media_loja2 = round(media(loja2['Avaliação da compra']),2)
media_loja2
# Out:
# 4.04

# %%
# Loja 3
def media(lista):
  calculo = sum(lista) / len(lista)
  return calculo

media_loja3 = round(media(loja3['Avaliação da compra']),2)
media_loja3
# Out:
# 4.05

# %%
# Loja 4
def media(lista):
  calculo = sum(lista) / len(lista)
  return calculo

media_loja4 = round(media(loja4['Avaliação da compra']),3)
media_loja4
# Out:
# 3.996

# %%
print(f'A avaliação média na loja 1 foi de: {media_loja1}')
print(f'A avaliação média na loja 2 foi de: {media_loja2}')
print(f'A avaliação média na loja 3 foi de: {media_loja3}')
print(f'A avaliação média na loja 4 foi de: {media_loja4}')
# Out:
# A avaliação média na loja 1 foi de: 3.98
# A avaliação média na loja 2 foi de: 4.04
# A avaliação média na loja 3 foi de: 4.05
# A avaliação média na loja 4 foi de: 3.996

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# 1. Definir dicionario para armazenar produtos vendidos
# 2. Criar função para identificar produto ou produtos mais e menos vendidos
# 3. Mostrar itens mais e menos vendidos

# %%
# Loja 1
# - Criar dicionario para os produtos
produtos_loja1 = {}

for produto in loja['Produto']:
    if produto in produtos_loja1:
        produtos_loja1[produto] += 1
    else:
        produtos_loja1[produto] = 1

# - Função para identificar o produto mais vendido
def identificar_produtos_mais_vendidos(dicionario_produtos):
    maior_valor = max(dicionario_produtos.values())
    produtos_maior_empate = []

    for produto, qtd in dicionario_produtos.items():
        if qtd == maior_valor:
            produtos_maior_empate.append(produto)

    return produtos_maior_empate, maior_valor

# - Função para identificar o produto menos vendido
def identificar_produtos_menos_vendidos(dicionario_produtos):
    menor_valor = min(dicionario_produtos.values())
    produtos_menor_empate = []

    for produto, qtd in dicionario_produtos.items():
        if qtd == menor_valor:
            produtos_menor_empate.append(produto)

    return produtos_menor_empate, menor_valor

produtos_mais_vendidos_loja1 = identificar_produtos_mais_vendidos(produtos_loja1)
produtos_menos_vendidos_loja1 = identificar_produtos_menos_vendidos(produtos_loja1)

# %%
# loja 2
produtos_loja2 = {}

for produto in loja2['Produto']:
    if produto in produtos_loja2:
        produtos_loja2[produto] += 1
    else:
        produtos_loja2[produto] = 1

produtos_mais_vendidos_loja2 = identificar_produtos_mais_vendidos(produtos_loja2)
produtos_menos_vendidos_loja2 = identificar_produtos_menos_vendidos(produtos_loja2)

# %%
# loja 3
produtos_loja3 = {}

for produto in loja3['Produto']:
    if produto in produtos_loja3:
        produtos_loja3[produto] += 1
    else:
        produtos_loja3[produto] = 1

produtos_mais_vendidos_loja3 = identificar_produtos_mais_vendidos(produtos_loja3)
produtos_menos_vendidos_loja3 = identificar_produtos_menos_vendidos(produtos_loja3)

# %%
# loja 4
produtos_loja4 = {}

for produto in loja4['Produto']:
    if produto in produtos_loja4:
        produtos_loja4[produto] += 1
    else:
        produtos_loja4[produto] = 1

produtos_mais_vendidos_loja4 = identificar_produtos_mais_vendidos(produtos_loja4)
produtos_menos_vendidos_loja4 = identificar_produtos_menos_vendidos(produtos_loja4)

# %%
# Mostrar produtos mais vendidos de cada loja
print(f'O(s) produto(s) mais vendido(s) na loja 1: {produtos_mais_vendidos_loja1}')
print(f'O(s) produto(s) mais vendido(s) na loja 2: {produtos_mais_vendidos_loja2}')
print(f'O(s) produto(s) mais vendido(s) na loja 3: {produtos_mais_vendidos_loja3}')
print(f'O(s) produto(s) mais vendido(s) na loja 4: {produtos_mais_vendidos_loja4}')
# Out:
# O(s) produto(s) mais vendido(s) na loja 1: (['Micro-ondas', 'TV Led UHD 4K', 'Guarda roupas'], 60)
# O(s) produto(s) mais vendido(s) na loja 2: (['Iniciando em programação'], 65)
# O(s) produto(s) mais vendido(s) na loja 3: (['Kit banquetas'], 57)
# O(s) produto(s) mais vendido(s) na loja 4: (['Cama box'], 62)

# %%
# Mostrar produtos menos vendidos de cada loja
print(f'O(s) produto(s) menos vendido(s) na loja 1: {produtos_menos_vendidos_loja1}')
print(f'O(s) produto(s) menos vendido(s) na loja 2: {produtos_menos_vendidos_loja2}')
print(f'O(s) produto(s) menos vendido(s) na loja 3: {produtos_menos_vendidos_loja3}')
print(f'O(s) produto(s) menos vendido(s) na loja 4: {produtos_menos_vendidos_loja4}')
# Out:
# O(s) produto(s) menos vendido(s) na loja 1: (['Headset', 'Celular ABXY'], 33)
# O(s) produto(s) menos vendido(s) na loja 2: (['Jogo de tabuleiro'], 32)
# O(s) produto(s) menos vendido(s) na loja 3: (['Blocos de montar'], 35)
# O(s) produto(s) menos vendido(s) na loja 4: (['Guitarra'], 33)

# %% [markdown]
# # 5. Frete Médio por Loja

# %% [markdown]
# 1. Criar uma função para calcular a media
# 2. Aplicar a função em todas as lojas

# %%
# loja 1

def media(lista):
  calculo = sum(lista) / len(lista)
  return calculo

media_frete_loja1 = round(media(loja['Frete']),2)

# %%
# loja 2

media_frete_loja2 = round(media(loja2['Frete']),2)

# %%
# loja 3

media_frete_loja3 = round(media(loja3['Frete']),2)

# %%
# loja 4

media_frete_loja4 = round(media(loja4['Frete']),2)

# %%
# Mostrar custo médio com frete em cada loja

print(f'O custo médio com frete na loja 1 foi de: R$ {media_frete_loja1}')
print(f'O custo médio com frete na loja 2 foi de: R$ {media_frete_loja2}')
print(f'O custo médio com frete na loja 3 foi de: R$ {media_frete_loja3}')
print(f'O custo médio com frete na loja 4 foi de: R$ {media_frete_loja4}')
# Out:
# O custo médio com frete na loja 1 foi de: R$ 34.69
# O custo médio com frete na loja 2 foi de: R$ 33.62
# O custo médio com frete na loja 3 foi de: R$ 33.07
# O custo médio com frete na loja 4 foi de: R$ 31.28

# %% [markdown]
# # 6 - Graficos

# %%
# Loja 1

categorias = list(categorias_loja1.keys())
vendas = list(categorias_loja1.values())

plt.figure(figsize=(5, 5))
plt.pie(vendas, labels=categorias, autopct='%1.1f%%', startangle=90)
plt.title("Distribuição de Vendas por Categoria - Loja 1")
plt.axis('equal')
plt.show()

# %%
# Loja 2 - Categorias

categorias = list(categorias_loja2.keys())
vendas = list(categorias_loja2.values())

plt.figure(figsize=(5, 5))
plt.pie(vendas, labels=categorias, autopct='%1.1f%%', startangle=90)
plt.title("Distribuição de Vendas por Categoria - Loja 2")
plt.axis('equal')
plt.show()

# %%
# Loja 3  - Categorias

categorias = list(categorias_loja3.keys())
vendas = list(categorias_loja3.values())

plt.figure(figsize=(5, 5))
plt.pie(vendas, labels=categorias, autopct='%1.1f%%', startangle=90)
plt.title("Distribuição de Vendas por Categoria - Loja 3")
plt.axis('equal')
plt.show()

# %%
# Loja 4 - Categorias

categorias = list(categorias_loja4.keys())
vendas = list(categorias_loja4.values())

plt.figure(figsize=(5, 5))
plt.pie(vendas, labels=categorias, autopct='%1.1f%%', startangle=90)
plt.title("Distribuição de Vendas por Categoria - Loja 4")
plt.axis('equal')
plt.show()

# %% [markdown]
# # Relatório Final 📝
#
# Para decidirmos em qual loja o Senhor João deverá vender, realizamos primeiramente uma **análise exploratória** dos dados de cada loja a fim de compreendermos o cenário individual de desempenho.
#
# Começamos observando o **faturamento total** de cada loja. A **Loja 1** apresentou o maior faturamento, com aproximadamente **1,5 milhão**, enquanto a **Loja 4** teve o menor, com cerca de **1,3 milhão**.
#
# *Gráfico de faturamento*
#
# ---

# %%
import matplotlib.pyplot as plt

# Grafico de barras para mostrarmos o faturamento por loja

plt.bar(faturamento_lojas.keys(), faturamento_lojas.values())
plt.title("Faturamento por Loja")
plt.xlabel("Lojas")
plt.ylabel("Faturamento R$")

plt.show()

# %% [markdown]
# Em seguida, analisamos as **categorias mais vendidas por loja**. Como resultado, identificamos que a categoria **Móveis** foi a mais relevante, representando entre **18,7% e 21,2%** das vendas totais nas quatro lojas.
#
# Aprofundando a análise dentro de cada loja, identificamos os **produtos mais e menos vendidos**:
#
# **Loja 1**
# - Mais vendidos: Micro-ondas, TV Led UHD 4K, Guarda-roupas
# - Menos vendidos: Headset, Celular ABXY
#
# **Loja 2**
# - Mais vendidos: Iniciando em programação
# - Menos vendidos: Jogo de tabuleiro
#
# **Loja 3**
# - Mais vendidos: Kit banquetas
# - Menos vendidos: Blocos de montar
#
# **Loja 4**
# - Mais vendidos: Cama box
# - Menos vendidos: Guitarra
#
# Em relação ao **frete médio**, a **Loja 4** se destacou positivamente com o menor custo: **1,28**, enquanto a **Loja 1** teve o maior custo: **34,69**.
#
# Quanto às **avaliações dos clientes**, os resultados foram os seguintes:
# - Loja 3: 4,05 (1º)
# - Loja 2: 4,04 (2º)
# - Loja 4: 4,00 (3º)
# - Loja 1: 3,98 (4º)
#
# *Gráfico das avaliações*
#
# ---

# %%
import matplotlib.pyplot as plt

# Grafico de linhas para avaliarmos as avaliações por loja
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
avaliacoes = [media_loja1, media_loja2, media_loja3, media_loja4]

plt.plot(lojas, avaliacoes, color='orange', marker='o', linewidth=2)
plt.title('Avaliação Média por Loja')
plt.xlabel('Lojas')
plt.ylabel('Nota (0 a 5)')
plt.ylim(3.50, 5.0)

# Rotulos da linha
for i in range(len(lojas)):
    plt.text(i, avaliacoes[i], f'{avaliacoes[i]:.2f}', ha='center')

plt.show()

# %% [markdown]
# ## Conclusão e recomendação
#
# Considerando os indicadores analisados, como **faturamento**, **produtos mais/menos vendidos**, **avaliações dos clientes**, **distribuição por categoria** e **frete médio**, a recomendação é que o Senhor João opte por **vender a Loja 4**.
#
# Apesar de apresentar uma boa avaliação (4,00) e o menor custo de frete, a Loja 4 tem o **menor faturamento entre todas as lojas**, o que a torna **menos atrativa comercialmente**. Já a Loja 1, mesmo tendo a avaliação mais baixa, possui o maior faturamento e maior volume de vendas — o que a torna mais estratégica para manter.
#
# Portanto, com base nos dados, gráficos e indicadores apresentados, a **Loja 4** é a mais adequada para venda neste momento.
#
# ---
